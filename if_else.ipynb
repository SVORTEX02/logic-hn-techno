# %%
# dictionary bhi use kr skte h so like hm age:age(number in words ) k sath check kr sake
age=input("enter the age ").strip()
if age.isdigit() :
    age=int(age)
    if int(age)>18 :
        print("eligble for voing")
    else:
        print("not eligble for voting")
else:
    print("Invalid input. Please enter a valid number.")
# Out:
# eligble for voing

# %%
# even -odd
num=input("enter the number")
if num.isdigit():
    num=int(num)
    if num%2==0:
        print("even")
    else:
        print("odd")
else:
    print("please enter a  number!!")
    num=input("enter the number")
# Out:
# even

# %%
    # even odd 2-method
    
num1=input("enter the number")
if num1.isdigit():
    if num & 1==0:
        print("even")
    else:
        print("odd")
else:
    print("please enter a valid number")
# Out:
# even

# %%
# number divisible by 7
num2=input("enter a number")
if num2.isdigit():
    if int(num2)%7==0:
        print("the number is divisble by 7")
    else:
        print("the number is not divisble by 7")
else:
    print("please enter valid number")
# Out:
# the number is divisble by 7

# %%
# number multiple of  5 
num5=input("enter the number").strip()

if num5.isdigit() and int(num5)>0:
    if  int(num5)%5==0:
        print("hello")
    else:
        print("Bye")
else:
    print("enter a valid number")
# Out:
# hello

# %%
# method-2 for multiplier of 5

num6=input("enter the number").strip()
if num6.isdigit() and int(num6)>0:
    lastDigit=int(num6)%10
    # print(lastDigit)
    if lastDigit==0 or lastDigit==5:
        print("Hello")
    else:
        print("Bye")
else:
    print("enter a valid number")
# Out:
# Bye

# %%
unit=input("enter unit").strip()
charge=0
if unit.isdigit() and int(unit)>0:
    unit=int(unit)
    if unit<=100:charge=0
    elif  unit<=200: charge=(unit-100)*5
    else:  charge=(100*5)+(unit-200)*10
    print(f"total charges:{charge}")
else:
    print("enter a valid unit")
# Out:
# total charges:0

# %%
num7=input("enter a number ")
if num7.isdigit() and int(num7)>0: print(f"last one{int(num7)%10}")
else: print("enter a valid number")
# Out:
# last one7

# %%
# to get a last digit 
n=input("enter the number")
if n.isdigit() and int(n)>0:
    last=n[-1]
    print(last)
else:
    print("enter once again")
# Out:
# 3

# %%
# to check if the last digit of a number is divsible by three
p=input("enter number")
if p.isdigit():
    p=int(p)
    l=(p%10)//3
    print(f"the number {p} is divisible by 3")
else:
    print("enter a vlaid number")
# Out:
# the number 1234 is divisible by 3

# %%
# method 2
m=input("enter the number")
if m.isdigit() and int(m)>0:
    m=int(m)
    if m==3 or m==6 or m==9:
        print(f"the number{m} is divisble by 3")
    else:
        print(f"number {m} not divisible by 3")
else:
    print("enter the number again!!")
# Out:
# number 99 not divisible by 3

# %%
mark=input("enter the percentage").strip()
if mark.isdigit() and int(mark)>0:
    mark=int(mark)
    if mark>90:
        print('A')
    elif mark>80 :
        print('B')
    elif mark>=60:
        print('C')
    else:
        print('D')
else:
    print('enter valid marks')
# Out:
# B

# %%
cost=input("enter  price of bike: ")

if cost.isdigit() and int(cost)>0:
    cost=int(cost)
    tax=0
    if cost>10000:
        tax=15
    elif cost>5000:
        tax=10
    elif cost<=5000:
        tax=5
    
    tax_amount = (tax * cost) / 100
    total_cost = cost + tax_amount

    print(f"tax Rate{tax}")
    print(f"road tax amount: {tax_amount}")
    print(f"total price after tax: {total_cost}")
else:
    print("enter a valid cost")
# Out:
# tax Rate5
# road tax amount: 10.0
# total price after tax: 210.0

# %%
# leap year
year=input("enter a year").strip()
if year.isdigit():
    year=int(year)
    if year%4==0 or (year%100!=0 or year%400==0 ):
        print(f"{year} is a leap year")
    else:
        print(f"{year} is not a leap year")
# Out:
# 2780 is a leap year

# %%
day=input("enter  number:").strip()
if day.isdigit():
    day=int(day)
    if day==1:
        print("Monday")
    elif day==2:
        print("Tuesday")
    elif day==3:
        print("Wednesday")
    elif day==4:
        print("thursday")
    elif day==5:
        print("friday")
    elif day==6:
        print("saturday")
    elif day==7:
        print("sunday")
    else:
        print(f"there is no such day on this {day}")
else:
    pass
# Out:
# Tuesday

# %%
# city name
city=input("enter your city").strip().lower()
if city=='delhi':
    print("Red Fort")
elif city=='agra':
    print("Taj Mahal")
elif city=='jaipur':
    print("jal mahal")
else:
    print("kindly enter city")
# Out:
# Red Fort

# %%
# program to check wether the number entred is three digit or not
nums=input("enter a number").strip()
nums=int(nums)
if nums>99:
    print(f"{nums} is three digit number")
else:
    print(f"this {nums} is not a three digit number")
# Out:
# this 12 is not a three digit number

# %%
nums=input("enter a number").strip()
nl=len(nums)

if nl==3:
    print(f"{nums} is three digit number")
else:
    print(f"{nums} is not three digti number")
# Out:
# 34567 is not three digti number

# %%
# lowest number out of the two numbers given
a=input("enter a number")
b=input("enter a number")

if a.isdigit() and b.isdigit():
    a=int(a)
    b=int(b)
    if a>b:
        print(f"{a} is greater than {b}")
    else:
        print(f"{b} is greater than {a}")
else:
    pass
# Out:
# 23 is greater than 2

# %%
num=input("enter integer value")

if num.isdigit():
    num=int(num)
    if num>0:
        print("number is positive and greATER than 0")
    else:
        print("number is smaller than zero")
else:
    print("enter integer")
# Out:
# number is positive and greATER than 0

# %%
k=input("enter number")
if k.isdigit():
    k=int(k)
    if k%2==0 and k%3==0:
        print("number is divisible by 2 and 3")
    else:
        print("number is not divisible by 2 and 3")
else:
    print("enter number again !!")
# Out:
# number is not divisible by 2 and 3

# %%
a=input("enter number")
b=input("enter seond number")
c=input("enter third number")

if a.isdigit() and b.isdigit() and c.isdigit():
    a=int(a)
    b=int(b)
    c=int(c)
    
    if a>b and a>c:
        print(f"{a} is greater than {b}")
    elif b>a and b>c:
        print(f"{b} is greater than {a}")
    else:
        print(f"{c} is greater than both {a} and {b}")
else:
    print("enter valid number")
# Out:
# 23 is greater than both 23 and 23

# %%
temp=input("enter temprature")
if temp.isdigit():
    temp=int(temp)
    if temp>100:print("Boiling temprature")
    else:print("not at boiling stage")
else:
    print("pelase enter a valid stage")
# Out:
# not at boiling stage

# %%
ch=input("enter a word").strip().lower()
vowel="aeiou"
if ch in vowel:
    print(f"the word has vowel {ch}")
else:
    print(f"{ch} is not vowel")
# Out:
# asdc is not vowel

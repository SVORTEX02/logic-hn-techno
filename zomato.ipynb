# %%
print("welcome to our zomato")
print("1.Sign-Up")
print("2.Login")
Sign_up=1
Login=2

flag=False

user_choice=input("enter your choice (1/2)?")
print(f"your choice- {user_choice}")

if user_choice.isdigit() and int(user_choice)==Sign_up:
    print("Directing to Sign-Up")
    flag=True
else:
    print("Directing to Login-Page")


if flag:
    # sign-up
    name=input("enter your name:")
    set_pass=input("enter password:")
    email=input("enter email:")
    
    print("Your Details:")
    print(f"USERNAME:{name} \n PASSWORD:{set_pass}  \n EMAIL:{email}")

    
else:
        
    user_name="vortex"
    password="vortex@123"


    print("Loading......")
    print("checking credentials........")


    # login
    user_input=input("enter your username:")
    user_pass=input("enter your password:")
    if user_input==user_name and user_pass==password:
        print(f"hello {user_name}! welcome back ")
    else:
        print(f"Wrong credentials try once again")
# Out:
# welcome to our zomato
# 1.Sign-Up
# 2.Login
# your choice 2
# Directing to Login-Page
# Loading......
# checking credentials........
# hello vortex! welcome back
